# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52269/Reinforcement_Learning_2269/blob/main/Lab2_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

machines = ['A', 'B', 'C']

N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': 0, 'B': 0, 'C': 0}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}

epsilon = 0.2
num_plays = 10
total_reward = 0

print("===== Epsilon-Greedy Multi-Armed Bandit =====")
print("Machines:", machines)
print("Epsilon:", epsilon)
print("Number of Plays:", num_plays)

for play in range(1, num_plays + 1):

    r = random.random()

    if r < epsilon:
        machine = random.choice(machines)
        decision = "Exploration"
    else:

        max_q = max(Q.values())
        best_machines = [m for m in machines if Q[m] == max_q]
        machine = random.choice(best_machines)
        decision = "Exploitation"

    print(f"\nPlay {play}")
    print(f"Random number = {r:.4f}")
    print(f"{decision}: Machine {machine}")

    reward = float(input(f"Enter reward for Machine {machine}: "))

    N[machine] += 1
    R[machine] += reward

    Q[machine] = Q[machine] + (reward - Q[machine]) / N[machine]

    total_reward += reward

    print(f"N({machine}) = {N[machine]}")
    print(f"R({machine}) = {R[machine]:.2f}")
    print(f"Q({machine}) = {Q[machine]:.2f}")

print("\n========== FINAL RESULTS ==========")

print("\nMachine\tN(a)\tR(a)\tQ(a)")

for machine in machines:
    print(f"{machine}\t{N[machine]}\t{R[machine]:.2f}\t{Q[machine]:.2f}")

print("\nTotal Reward after 10 plays =", total_reward)

best_machine = max(Q, key=Q.get)
print("Best Estimated Machine =", best_machine)
print("Best Q-value =", round(Q[best_machine], 2))
# Out:
# ===== Epsilon-Greedy Multi-Armed Bandit =====
# Machines: ['A', 'B', 'C']
# Epsilon: 0.2
# Number of Plays: 10
#
# Play 1
# Random number = 0.9259
# Exploitation: Machine B
# Enter reward for Machine B: 3
# N(B) = 1
# R(B) = 3.00
# Q(B) = 3.00
#
# Play 2
# Random number = 0.6823
# Exploitation: Machine B
# Enter reward for Machine B: 4
# N(B) = 2
# R(B) = 7.00
# Q(B) = 3.50
#
# Play 3
# Random number = 0.5882
# Exploitation: Machine B
# Enter reward for Machine B: 6
# N(B) = 3
# R(B) = 13.00
# Q(B) = 4.33
#
# Play 4
# Random number = 0.4309
# Exploitation: Machine B
# Enter reward for Machine B: 5
# N(B) = 4
# R(B) = 18.00
# Q(B) = 4.50
#
# Play 5
# Random number = 0.7607
# Exploitation: Machine B
# Enter reward for Machine B: 8
# N(B) = 5
# R(B) = 26.00
# Q(B) = 5.20
#
# Play 6
# Random number = 0.7869
# Exploitation: Machine B
# Enter reward for Machine B: 9
# N(B) = 6
# R(B) = 35.00
# Q(B) = 5.83
#
# Play 7
# Random number = 0.2423
# Exploitation: Machine B
# Enter reward for Machine B: 2
# N(B) = 7
# R(B) = 37.00
# Q(B) = 5.29
#
# Play 8
# Random number = 0.8914
# Exploitation: Machine B
# Enter reward for Machine B: 6
# N(B) = 8
# R(B) = 43.00
# Q(B) = 5.38
#
# Play 9
# Random number = 0.6634
# Exploitation: Machine B
# Enter reward for Machine B: 1
# N(B) = 9
# R(B) = 44.00
# Q(B) = 4.89
#
# Play 10
# Random number = 0.2478
# Exploitation: Machine B
# Enter reward for Machine B: 4
# N(B) = 10
# R(B) = 48.00
# Q(B) = 4.80
#
# ========== FINAL RESULTS ==========
#
# Machine	N(a)	R(a)	Q(a)
# A	0	0.00	0.00
# B	10	48.00	4.80
# C	0	0.00	0.00
#
# Total Reward after 10 plays = 48.0
# Best Estimated Machine = B
# Best Q-value = 4.8
